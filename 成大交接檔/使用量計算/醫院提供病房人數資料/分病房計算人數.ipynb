# %% [markdown]
# 引用

# %%
import pandas as pd
import os
from collections import Counter

# %% [markdown]
# 讀取資料

# %%
total_data=pd.read_excel(f"./病房人數.xlsx")

# %%
# 依照護理站分群
count_class = Counter(total_data["成本中心"])
count_class = count_class.keys()
# 將資料分組
group = total_data.groupby(['成本中心'])
for type in group.groups.keys():
    print(type)
# Out:
# DLI1
# DLN1
# DLN2
# DLN3
# DLN5
# DLN6
# DLN8
# DLRI

# %%
def take_data(data,n_day):
    data_copy = data.copy()
    # 總共要提取幾次
    for num in range(n_day, len(data_copy),1):
#         每次提取n筆
        for time in range(1,n_day+1,1):
            before_day = data_copy.loc[num-time:num-time,"該週總人數"]
            print(before_day)
#             print(type(before_day))
            data_copy.loc[num:num,f'前{time}週人數'] = before_day.values[0]

    return data_copy

# %% [markdown]
# 五病房資料

# %%
room5 = total_data[total_data['成本中心'] == 'DLN5'] 
room5
# 先計算每週總人數、平均人數、最多人數
room5['住院日期'] =  pd.to_datetime(room5['住院日期'])
room5['週'] = room5['住院日期'].dt.isocalendar().week
room5['年'] = room5['住院日期'].dt.isocalendar().year
room5['該週總人數'] = 0
# 先移除第53週
room5 = room5.drop(room5[room5['週'] == 53].index).reset_index(drop=True)
print()
# 計算一週總人數
for year in range(0,6,1):
    for num in range(1, 53,1):
        temp = room5[(room5['年'] == 2018+year) & (room5['週'] == num)]
        people_sum = temp['人數'].sum()
        people_max = temp['人數'].max()
        room5.loc[(room5['年'] == 2018+year) & (room5['週'] == num),'該週總人數'] = people_sum
        room5.loc[(room5['年'] == 2018+year) & (room5['週'] == num),'該週最多人'] = people_max
columns = ['週','年']     
room5.drop_duplicates(subset=columns, keep='last', inplace=True)
room5 = room5.reset_index(drop=True)

for num in range(1,len(room5),1):
        before_day = room5.loc[num-1:num-1,"該週總人數"]
        before_day_max = room5.loc[num-1:num-1,"該週最多人"]
        print(before_day)
#             print(type(before_day))
        room5.loc[num:num,f'前{1}週人數'] = before_day.values[0]
        room5.loc[num:num,f'前{1}週最多人'] = before_day_max.values[0]

# 計算前一週病人平均數

for year in range(0,6,1):
    for num in range(1, 53,1):
        temp = room5[(room5['年'] == 2018+year) & (room5['週'] == num)]
        people_avg = (temp['前1週人數'].values[0]/7).round(decimals = 2)
        room5.loc[(room5['年'] == 2018+year) & (room5['週'] == num),'前1週平均人數'] = people_avg
# Out:
# C:\Users\IDSL\AppData\Local\Temp\ipykernel_28056\26201255.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   room5['住院日期'] =  pd.to_datetime(room5['住院日期'])
# C:\Users\IDSL\AppData\Local\Temp\ipykernel_28056\26201255.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   room5['週'] = room5['住院日期'].dt.isocalendar().week
# C:\Users\IDSL\AppData\Local\Temp\ipykernel_28056\26201255.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   room5['年'] = room5['住院日期'].dt.isocalendar().year
# C:\Users\IDSL\AppData\Local\Temp\ipykernel_28056\26201255.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   room5['該週總人數'] = 0
# 0    180
# Name: 該週總人數, dtype: int64
# 1    199
# Name: 該週總人數, dtype: int64
# 2    195
# Name: 該週總人數, dtype: int64
# 3    210
# Name: 該週總人數, dtype: int64
# 4    185
# Name: 該週總人數, dtype: int64
# 5    154
# Name: 該週總人數, dtype: int64
# 6    126
# Name: 該週總人數, dtype: int64
# 7    189
# Name: 該週總人數, dtype: int64
# 8    192
# Name: 該週總人數, dtype: int64
# 9    206
# Name: 該週總人數, dtype: int64
# 10    208
# Name: 該週總人數, dtype: int64
# 11    180
# Name: 該週總人數, dtype: int64
# 12    164
# Name: 該週總人數, dtype: int64
# 13    147
# Name: 該週總人數, dtype: int64
# 14    208
# Name: 該週總人數, dtype: int64
# 15    208
# Name: 該週總人數, dtype: int64
# 16    186
# Name: 該週總人數, dtype: int64
# 17    191
# Name: 該週總人數, dtype: int64
# 18    148
# Name: 該週總人數, dtype: int64
# 19    185
# Name: 該週總人數, dtype: int64
# 20    186
# Name: 該週總人數, dtype: int64
# 21    173
# Name: 該週總人數, dtype: int64
# 22    173
# Name: 該週總人數, dtype: int64
# 23    183
# Name: 該週總人數, dtype: int64
# 24    191
# Name: 該週總人數, dtype: int64
# 25    206
# Name: 該週總人數, dtype: int64
# 26    246
# Name: 該週總人數, dtype: int64
# 27    202
# Name: 該週總人數, dtype: int64
# 28    176
# Name: 該週總人數, dtype: int64
# 29    203
# Name: 該週總人數, dtype: int64
# 30    207
# Name: 該週總人數, dtype: int64
# 31    239
# Name: 該週總人數, dtype: int64
# 32    215
# Name: 該週總人數, dtype: int64
# 33    181
# Name: 該週總人數, dtype: int64
# 34    193
# Name: 該週總人數, dtype: int64
# 35    181
# Name: 該週總人數, dtype: int64
# 36    224
# Name: 該週總人數, dtype: int64
# 37    245
# Name: 該週總人數, dtype: int64
# 38    193
# Name: 該週總人數, dtype: int64
# 39    228
# Name: 該週總人數, dtype: int64
# 40    175
# Name: 該週總人數, dtype: int64
# 41    234
# Name: 該週總人數, dtype: int64
# 42    178
# Name: 該週總人數, dtype: int64
# 43    214
# Name: 該週總人數, dtype: int64
# 44    192
# Name: 該週總人數, dtype: int64
# 45    171
# Name: 該週總人數, dtype: int64
# 46    128
# Name: 該週總人數, dtype: int64
# 47    165
# Name: 該週總人數, dtype: int64
# 48    146
# Name: 該週總人數, dtype: int64
# 49    202
# Name: 該週總人數, dtype: int64
# 50    185
# Name: 該週總人數, dtype: int64
# 51    236
# Name: 該週總人數, dtype: int64
# 52    170
# Name: 該週總人數, dtype: int64
# 53    223
# Name: 該週總人數, dtype: int64
# 54    190
# Name: 該週總人數, dtype: int64
# 55    186
# Name: 該週總人數, dtype: int64
# 56    151
# Name: 該週總人數, dtype: int64
# 57    175
# Name: 該週總人數, dtype: int64
# 58    269
# Name: 該週總人數, dtype: int64
# 59    216
# Name: 該週總人數, dtype: int64
# 60    203
# Name: 該週總人數, dtype: int64
# 61    223
# Name: 該週總人數, dtype: int64
# 62    211
# Name: 該週總人數, dtype: int64
# 63    246
# Name: 該週總人數, dtype: int64
# 64    192
# Name: 該週總人數, dtype: int64
# 65    143
# Name: 該週總人數, dtype: int64
# 66    233
# Name: 該週總人數, dtype: int64
# 67    233
# Name: 該週總人數, dtype: int64
# 68    217
# Name: 該週總人數, dtype: int64
# 69    188
# Name: 該週總人數, dtype: int64
# 70    197
# Name: 該週總人數, dtype: int64
# 71    202
# Name: 該週總人數, dtype: int64
# 72    192
# Name: 該週總人數, dtype: int64
# 73    161
# Name: 該週總人數, dtype: int64
# 74    164
# Name: 該週總人數, dtype: int64
# 75    179
# Name: 該週總人數, dtype: int64
# 76    210
# Name: 該週總人數, dtype: int64
# 77    196
# Name: 該週總人數, dtype: int64
# 78    201
# Name: 該週總人數, dtype: int64
# 79    194
# Name: 該週總人數, dtype: int64
# 80    187
# Name: 該週總人數, dtype: int64
# 81    218
# Name: 該週總人數, dtype: int64
# 82    173
# Name: 該週總人數, dtype: int64
# 83    184
# Name: 該週總人數, dtype: int64
# 84    223
# Name: 該週總人數, dtype: int64
# 85    141
# Name: 該週總人數, dtype: int64
# 86    175
# Name: 該週總人數, dtype: int64
# 87    235
# Name: 該週總人數, dtype: int64
# 88    185
# Name: 該週總人數, dtype: int64
# 89    191
# Name: 該週總人數, dtype: int64
# 90    185
# Name: 該週總人數, dtype: int64
# 91    172
# Name: 該週總人數, dtype: int64
# 92    215
# Name: 該週總人數, dtype: int64
# 93    161
# Name: 該週總人數, dtype: int64
# 94    188
# Name: 該週總人數, dtype: int64
# 95    186
# Name: 該週總人數, dtype: int64
# 96    145
# Name: 該週總人數, dtype: int64
# 97    181
# Name: 該週總人數, dtype: int64
# 98    196
# Name: 該週總人數, dtype: int64
# 99    242
# Name: 該週總人數, dtype: int64
# 100    192
# Name: 該週總人數, dtype: int64
# 101    186
# Name: 該週總人數, dtype: int64
# 102    230
# Name: 該週總人數, dtype: int64
# 103    223
# Name: 該週總人數, dtype: int64
# 104    168
# Name: 該週總人數, dtype: int64
# 105    161
# Name: 該週總人數, dtype: int64
# 106    152
# Name: 該週總人數, dtype: int64
# 107    37
# Name: 該週總人數, dtype: int64
# 108    45
# Name: 該週總人數, dtype: int64
# 109    212
# Name: 該週總人數, dtype: int64
# 110    211
# Name: 該週總人數, dtype: int64
# 111    194
# Name: 該週總人數, dtype: int64
# 112    169
# Name: 該週總人數, dtype: int64
# 113    186
# Name: 該週總人數, dtype: int64
# 114    193
# Name: 該週總人數, dtype: int64
# 115    236
# Name: 該週總人數, dtype: int64
# 116    255
# Name: 該週總人數, dtype: int64
# 117    237
# Name: 該週總人數, dtype: int64
# 118    252
# Name: 該週總人數, dtype: int64
# 119    252
# Name: 該週總人數, dtype: int64
# 120    263
# Name: 該週總人數, dtype: int64
# 121    242
# Name: 該週總人數, dtype: int64
# 122    245
# Name: 該週總人數, dtype: int64
# 123    237
# Name: 該週總人數, dtype: int64
# 124    171
# Name: 該週總人數, dtype: int64
# 125    183
# Name: 該週總人數, dtype: int64
# 126    182
# Name: 該週總人數, dtype: int64
# 127    254
# Name: 該週總人數, dtype: int64
# 128    264
# Name: 該週總人數, dtype: int64
# 129    213
# Name: 該週總人數, dtype: int64
# 130    268
# Name: 該週總人數, dtype: int64
# 131    220
# Name: 該週總人數, dtype: int64
# 132    205
# Name: 該週總人數, dtype: int64
# 133    209
# Name: 該週總人數, dtype: int64
# 134    218
# Name: 該週總人數, dtype: int64
# 135    247
# Name: 該週總人數, dtype: int64
# 136    275
# Name: 該週總人數, dtype: int64
# 137    207
# Name: 該週總人數, dtype: int64
# 138    261
# Name: 該週總人數, dtype: int64
# 139    223
# Name: 該週總人數, dtype: int64
# 140    223
# Name: 該週總人數, dtype: int64
# 141    241
# Name: 該週總人數, dtype: int64
# 142    267
# Name: 該週總人數, dtype: int64
# 143    175
# Name: 該週總人數, dtype: int64
# 144    167
# Name: 該週總人數, dtype: int64
# 145    261
# Name: 該週總人數, dtype: int64
# 146    226
# Name: 該週總人數, dtype: int64
# 147    197
# Name: 該週總人數, dtype: int64
# 148    236
# Name: 該週總人數, dtype: int64
# 149    198
# Name: 該週總人數, dtype: int64
# 150    264
# Name: 該週總人數, dtype: int64
# 151    213
# Name: 該週總人數, dtype: int64
# 152    248
# Name: 該週總人數, dtype: int64
# 153    185
# Name: 該週總人數, dtype: int64
# 154    210
# Name: 該週總人數, dtype: int64
# 155    207
# Name: 該週總人數, dtype: int64
# 156    217
# Name: 該週總人數, dtype: int64
# 157    274
# Name: 該週總人數, dtype: int64
# 158    262
# Name: 該週總人數, dtype: int64
# 159    224
# Name: 該週總人數, dtype: int64
# 160    214
# Name: 該週總人數, dtype: int64
# 161    16
# Name: 該週總人數, dtype: int64
# 162    166
# Name: 該週總人數, dtype: int64
# 163    256
# Name: 該週總人數, dtype: int64
# 164    227
# Name: 該週總人數, dtype: int64
# 165    231
# Name: 該週總人數, dtype: int64
# 166    251
# Name: 該週總人數, dtype: int64
# 167    228
# Name: 該週總人數, dtype: int64
# 168    202
# Name: 該週總人數, dtype: int64
# 169    217
# Name: 該週總人數, dtype: int64
# 170    241
# Name: 該週總人數, dtype: int64
# 171    163
# Name: 該週總人數, dtype: int64
# 172    212
# Name: 該週總人數, dtype: int64
# 173    206
# Name: 該週總人數, dtype: int64
# 174    194
# Name: 該週總人數, dtype: int64
# 175    182
# Name: 該週總人數, dtype: int64
# 176    194
# Name: 該週總人數, dtype: int64
# 177    211
# Name: 該週總人數, dtype: int64
# 178    187
# Name: 該週總人數, dtype: int64
# 179    187
# Name: 該週總人數, dtype: int64
# 180    177
# Name: 該週總人數, dtype: int64
# 181    200
# Name: 該週總人數, dtype: int64
# 182    219
# Name: 該週總人數, dtype: int64
# 183    208
# Name: 該週總人數, dtype: int64
# 184    197
# Name: 該週總人數, dtype: int64
# 185    206
# Name: 該週總人數, dtype: int64
# 186    193
# Name: 該週總人數, dtype: int64
# 187    190
# Name: 該週總人數, dtype: int64
# 188    198
# Name: 該週總人數, dtype: int64
# 189    209
# Name: 該週總人數, dtype: int64
# 190    231
# Name: 該週總人數, dtype: int64
# 191    233
# Name: 該週總人數, dtype: int64
# 192    236
# Name: 該週總人數, dtype: int64
# 193    164
# Name: 該週總人數, dtype: int64
# 194    262
# Name: 該週總人數, dtype: int64
# 195    185
# Name: 該週總人數, dtype: int64
# 196    145
# Name: 該週總人數, dtype: int64
# 197    157
# Name: 該週總人數, dtype: int64
# 198    218
# Name: 該週總人數, dtype: int64
# 199    213
# Name: 該週總人數, dtype: int64
# 200    246
# Name: 該週總人數, dtype: int64
# 201    212
# Name: 該週總人數, dtype: int64
# 202    233
# Name: 該週總人數, dtype: int64
# 203    177
# Name: 該週總人數, dtype: int64
# 204    170
# Name: 該週總人數, dtype: int64
# 205    200
# Name: 該週總人數, dtype: int64
# 206    214
# Name: 該週總人數, dtype: int64
# 207    230
# Name: 該週總人數, dtype: int64
# 208    224
# Name: 該週總人數, dtype: int64
# 209    231
# Name: 該週總人數, dtype: int64
# 210    217
# Name: 該週總人數, dtype: int64
# 211    101
# Name: 該週總人數, dtype: int64
# 212    12
# Name: 該週總人數, dtype: int64
# 213    214
# Name: 該週總人數, dtype: int64
# 214    256
# Name: 該週總人數, dtype: int64
# 215    201
# Name: 該週總人數, dtype: int64
# 216    180
# Name: 該週總人數, dtype: int64
# 217    249
# Name: 該週總人數, dtype: int64
# 218    242
# Name: 該週總人數, dtype: int64
# 219    270
# Name: 該週總人數, dtype: int64
# 220    254
# Name: 該週總人數, dtype: int64
# 221    190
# Name: 該週總人數, dtype: int64
# 222    230
# Name: 該週總人數, dtype: int64
# 223    223
# Name: 該週總人數, dtype: int64
# 224    239
# Name: 該週總人數, dtype: int64
# 225    233
# Name: 該週總人數, dtype: int64
# 226    233
# Name: 該週總人數, dtype: int64
# 227    146
# Name: 該週總人數, dtype: int64
# 228    202
# Name: 該週總人數, dtype: int64
# 229    127
# Name: 該週總人數, dtype: int64
# 230    90
# Name: 該週總人數, dtype: int64
# 231    62
# Name: 該週總人數, dtype: int64
# 232    69
# Name: 該週總人數, dtype: int64
# 233    69
# Name: 該週總人數, dtype: int64
# 234    179
# Name: 該週總人數, dtype: int64
# 235    208
# Name: 該週總人數, dtype: int64
# 236    135
# Name: 該週總人數, dtype: int64
# 237    142
# Name: 該週總人數, dtype: int64
# 238    159
# Name: 該週總人數, dtype: int64
# 239    143
# Name: 該週總人數, dtype: int64
# 240    155
# Name: 該週總人數, dtype: int64
# 241    155
# Name: 該週總人數, dtype: int64
# 242    159
# Name: 該週總人數, dtype: int64
# 243    149
# Name: 該週總人數, dtype: int64
# 244    174
# Name: 該週總人數, dtype: int64
# 245    214
# Name: 該週總人數, dtype: int64
# 246    254
# Name: 該週總人數, dtype: int64
# 247    245
# Name: 該週總人數, dtype: int64
# 248    239
# Name: 該週總人數, dtype: int64
# 249    279
# Name: 該週總人數, dtype: int64
# 250    333
# Name: 該週總人數, dtype: int64
# 251    289
# Name: 該週總人數, dtype: int64
# 252    257
# Name: 該週總人數, dtype: int64
# 253    255
# Name: 該週總人數, dtype: int64
# 254    199
# Name: 該週總人數, dtype: int64
# 255    246
# Name: 該週總人數, dtype: int64
# 256    224
# Name: 該週總人數, dtype: int64
# 257    227
# Name: 該週總人數, dtype: int64
# 258    224
# Name: 該週總人數, dtype: int64
# 259    219
# Name: 該週總人數, dtype: int64
# 260    256
# Name: 該週總人數, dtype: int64
# 261    216
# Name: 該週總人數, dtype: int64
# 262    106
# Name: 該週總人數, dtype: int64
# 263    89
# Name: 該週總人數, dtype: int64
# 264    209
# Name: 該週總人數, dtype: int64
# 265    265
# Name: 該週總人數, dtype: int64
# 266    274
# Name: 該週總人數, dtype: int64
# 267    279
# Name: 該週總人數, dtype: int64
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [5], in <cell line: 32>()
#      33 for num in range(1, 53,1):
#      34     temp = room5[(room5['年'] == 2018+year) & (room5['週'] == num)]
# ---> 35     people_avg = (temp['前1週人數'].values[0]/7).round(decimals = 2)
#      36     room5.loc[(room5['年'] == 2018+year) & (room5['週'] == num),'前1週平均人數'] = people_avg
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
room5

# %%
room5.to_csv(f'./五病房人數.csv',index=False, encoding='utf_8_sig')
