# %% [markdown]
# 引用

# %%
import pandas as pd
import os
from collections import Counter

# %% [markdown]
# 讀取資料

# %%
total_data=pd.read_excel(f"./病房人數.xlsx")

# %%
# 依照護理站分群
count_class = Counter(total_data["成本中心"])
count_class = count_class.keys()
# 將資料分組
group = total_data.groupby(['成本中心'])
for type in group.groups.keys():
    print(type)
# Out:
# DLI1
# DLN1
# DLN2
# DLN3
# DLN5
# DLN6
# DLN8
# DLRI

# %%
def take_data(data,n_day):
    data_copy = data.copy()
    # 總共要提取幾次
    for num in range(n_day, len(data_copy),1):
#         每次提取n筆
        for time in range(1,n_day+1,1):
            before_day = data_copy.loc[num-time:num-time,"該週總人數"]
            print(before_day)
#             print(type(before_day))
            data_copy.loc[num:num,f'前{time}週人數'] = before_day.values[0]

    return data_copy

# %% [markdown]
# 五病房資料

# %%
room5 = total_data[total_data['成本中心'] == 'DLN5'] 
room5
# 先計算每週總人數、平均人數、最多人數
room5['住院日期'] =  pd.to_datetime(room5['住院日期'])
room5['週'] = room5['住院日期'].dt.isocalendar().week
room5['年'] = room5['住院日期'].dt.isocalendar().year
room5['該週總人數'] = 0
# 先移除第53週
room5 = room5.drop(room5[room5['週'] == 53].index).reset_index(drop=True)
# 計算一週總人數
for year in range(0,6,1):
    for num in range(1, 53,1):
        temp = room5[(room5['年'] == 2018+year) & (room5['週'] == num)]
        people_sum = temp['人數'].sum()
        people_max = temp['人數'].max()
        room5.loc[(room5['年'] == 2018+year) & (room5['週'] == num),'該週總人數'] = people_sum
        room5.loc[(room5['年'] == 2018+year) & (room5['週'] == num),'該週最多人'] = people_max
columns = ['週','年']     
room5.drop_duplicates(subset=columns, keep='last', inplace=True)
room5 = room5.reset_index(drop=True)

for num in range(1,len(room5),1):
        before_day = room5.loc[num-1:num-1,"該週總人數"]
        before_day_max = room5.loc[num-1:num-1,"該週最多人"]
        print(before_day)
#             print(type(before_day))
        room5.loc[num:num,f'前{1}週人數'] = before_day.values[0]
        room5.loc[num:num,f'前{1}週最多人'] = before_day_max.values[0]

# 計算前一週病人平均數

for year in range(0,6,1):
    for num in range(1, 53,1):
        temp = room5[(room5['年'] == 2018+year) & (room5['週'] == num)]
        people_avg = (temp['前1週人數'].values[0]/7).round(decimals = 2)
        room5.loc[(room5['年'] == 2018+year) & (room5['週'] == num),'前1週平均人數'] = people_avg
# Out:
# C:\Users\IDSL\AppData\Local\Temp\ipykernel_13732\510207118.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   room5['住院日期'] =  pd.to_datetime(room5['住院日期'])
# C:\Users\IDSL\AppData\Local\Temp\ipykernel_13732\510207118.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   room5['週'] = room5['住院日期'].dt.isocalendar().week
# C:\Users\IDSL\AppData\Local\Temp\ipykernel_13732\510207118.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   room5['年'] = room5['住院日期'].dt.isocalendar().year
# C:\Users\IDSL\AppData\Local\Temp\ipykernel_13732\510207118.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   room5['該週總人數'] = 0
# C:\Users\IDSL\AppData\Local\Temp\ipykernel_13732\510207118.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   room5.loc[(room5['年'] == 2018+year) & (room5['週'] == num),'該週最多人'] = people_max
# C:\Users\IDSL\AppData\Local\Temp\ipykernel_13732\510207118.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   room5.drop_duplicates(subset=columns, keep='last', inplace=True)
# 0    180
# Name: 該週總人數, dtype: int64
# 1    199
# Name: 該週總人數, dtype: int64
# 2    195
# Name: 該週總人數, dtype: int64
# 3    210
# Name: 該週總人數, dtype: int64
# 4    185
# Name: 該週總人數, dtype: int64
# 5    154
# Name: 該週總人數, dtype: int64
# 6    126
# Name: 該週總人數, dtype: int64
# 7    189
# Name: 該週總人數, dtype: int64
# 8    192
# Name: 該週總人數, dtype: int64
# 9    206
# Name: 該週總人數, dtype: int64
# 10    208
# Name: 該週總人數, dtype: int64
# 11    180
# Name: 該週總人數, dtype: int64
# 12    164
# Name: 該週總人數, dtype: int64
# 13    147
# Name: 該週總人數, dtype: int64
# 14    208
# Name: 該週總人數, dtype: int64
# 15    208
# Name: 該週總人數, dtype: int64
# 16    186
# Name: 該週總人數, dtype: int64
# 17    191
# Name: 該週總人數, dtype: int64
# 18    148
# Name: 該週總人數, dtype: int64
# 19    185
# Name: 該週總人數, dtype: int64
# 20    186
# Name: 該週總人數, dtype: int64
# 21    173
# Name: 該週總人數, dtype: int64
# 22    173
# Name: 該週總人數, dtype: int64
# 23    183
# Name: 該週總人數, dtype: int64
# 24    191
# Name: 該週總人數, dtype: int64
# 25    206
# Name: 該週總人數, dtype: int64
# 26    246
# Name: 該週總人數, dtype: int64
# 27    202
# Name: 該週總人數, dtype: int64
# 28    176
# Name: 該週總人數, dtype: int64
# 29    203
# Name: 該週總人數, dtype: int64
# 30    207
# Name: 該週總人數, dtype: int64
# 31    239
# Name: 該週總人數, dtype: int64
# 32    215
# Name: 該週總人數, dtype: int64
# 33    181
# Name: 該週總人數, dtype: int64
# 34    193
# Name: 該週總人數, dtype: int64
# 35    181
# Name: 該週總人數, dtype: int64
# 36    224
# Name: 該週總人數, dtype: int64
# 37    245
# Name: 該週總人數, dtype: int64
# 38    193
# Name: 該週總人數, dtype: int64
# 39    228
# Name: 該週總人數, dtype: int64
# 40    175
# Name: 該週總人數, dtype: int64
# 41    234
# Name: 該週總人數, dtype: int64
# 42    178
# Name: 該週總人數, dtype: int64
# 43    214
# Name: 該週總人數, dtype: int64
# 44    192
# Name: 該週總人數, dtype: int64
# 45    171
# Name: 該週總人數, dtype: int64
# 46    128
# Name: 該週總人數, dtype: int64
# 47    165
# Name: 該週總人數, dtype: int64
# 48    146
# Name: 該週總人數, dtype: int64
# 49    202
# Name: 該週總人數, dtype: int64
# 50    185
# Name: 該週總人數, dtype: int64
# 51    236
# Name: 該週總人數, dtype: int64
# 52    170
# Name: 該週總人數, dtype: int64
# 53    223
# Name: 該週總人數, dtype: int64
# 54    190
# Name: 該週總人數, dtype: int64
# 55    186
# Name: 該週總人數, dtype: int64
# 56    151
# Name: 該週總人數, dtype: int64
# 57    175
# Name: 該週總人數, dtype: int64
# 58    269
# Name: 該週總人數, dtype: int64
# 59    216
# Name: 該週總人數, dtype: int64
# 60    203
# Name: 該週總人數, dtype: int64
# 61    223
# Name: 該週總人數, dtype: int64
# 62    211
# Name: 該週總人數, dtype: int64
# 63    246
# Name: 該週總人數, dtype: int64
# 64    192
# Name: 該週總人數, dtype: int64
# 65    143
# Name: 該週總人數, dtype: int64
# 66    233
# Name: 該週總人數, dtype: int64
# 67    233
# Name: 該週總人數, dtype: int64
# 68    217
# Name: 該週總人數, dtype: int64
# 69    188
# Name: 該週總人數, dtype: int64
# 70    197
# Name: 該週總人數, dtype: int64
# 71    202
# Name: 該週總人數, dtype: int64
# 72    192
# Name: 該週總人數, dtype: int64
# 73    161
# Name: 該週總人數, dtype: int64
# 74    164
# Name: 該週總人數, dtype: int64
# 75    179
# Name: 該週總人數, dtype: int64
# 76    210
# Name: 該週總人數, dtype: int64
# 77    196
# Name: 該週總人數, dtype: int64
# 78    201
# Name: 該週總人數, dtype: int64
# 79    194
# Name: 該週總人數, dtype: int64
# 80    187
# Name: 該週總人數, dtype: int64
# 81    218
# Name: 該週總人數, dtype: int64
# 82    173
# Name: 該週總人數, dtype: int64
# 83    184
# Name: 該週總人數, dtype: int64
# 84    223
# Name: 該週總人數, dtype: int64
# 85    141
# Name: 該週總人數, dtype: int64
# 86    175
# Name: 該週總人數, dtype: int64
# 87    235
# Name: 該週總人數, dtype: int64
# 88    185
# Name: 該週總人數, dtype: int64
# 89    191
# Name: 該週總人數, dtype: int64
# 90    185
# Name: 該週總人數, dtype: int64
# 91    172
# Name: 該週總人數, dtype: int64
# 92    215
# Name: 該週總人數, dtype: int64
# 93    161
# Name: 該週總人數, dtype: int64
# 94    188
# Name: 該週總人數, dtype: int64
# 95    186
# Name: 該週總人數, dtype: int64
# 96    145
# Name: 該週總人數, dtype: int64
# 97    181
# Name: 該週總人數, dtype: int64
# 98    196
# Name: 該週總人數, dtype: int64
# 99    242
# Name: 該週總人數, dtype: int64
# 100    192
# Name: 該週總人數, dtype: int64
# 101    186
# Name: 該週總人數, dtype: int64
# 102    230
# Name: 該週總人數, dtype: int64
# 103    223
# Name: 該週總人數, dtype: int64
# 104    168
# Name: 該週總人數, dtype: int64
# 105    161
# Name: 該週總人數, dtype: int64
# 106    152
# Name: 該週總人數, dtype: int64
# 107    37
# Name: 該週總人數, dtype: int64
# 108    45
# Name: 該週總人數, dtype: int64
# 109    212
# Name: 該週總人數, dtype: int64
# 110    211
# Name: 該週總人數, dtype: int64
# 111    194
# Name: 該週總人數, dtype: int64
# 112    169
# Name: 該週總人數, dtype: int64
# 113    186
# Name: 該週總人數, dtype: int64
# 114    193
# Name: 該週總人數, dtype: int64
# 115    236
# Name: 該週總人數, dtype: int64
# 116    255
# Name: 該週總人數, dtype: int64
# 117    237
# Name: 該週總人數, dtype: int64
# 118    252
# Name: 該週總人數, dtype: int64
# 119    252
# Name: 該週總人數, dtype: int64
# 120    263
# Name: 該週總人數, dtype: int64
# 121    242
# Name: 該週總人數, dtype: int64
# 122    245
# Name: 該週總人數, dtype: int64
# 123    237
# Name: 該週總人數, dtype: int64
# 124    171
# Name: 該週總人數, dtype: int64
# 125    183
# Name: 該週總人數, dtype: int64
# 126    182
# Name: 該週總人數, dtype: int64
# 127    254
# Name: 該週總人數, dtype: int64
# 128    264
# Name: 該週總人數, dtype: int64
# 129    213
# Name: 該週總人數, dtype: int64
# 130    268
# Name: 該週總人數, dtype: int64
# 131    220
# Name: 該週總人數, dtype: int64
# 132    205
# Name: 該週總人數, dtype: int64
# 133    209
# Name: 該週總人數, dtype: int64
# 134    218
# Name: 該週總人數, dtype: int64
# 135    247
# Name: 該週總人數, dtype: int64
# 136    275
# Name: 該週總人數, dtype: int64
# 137    207
# Name: 該週總人數, dtype: int64
# 138    261
# Name: 該週總人數, dtype: int64
# 139    223
# Name: 該週總人數, dtype: int64
# 140    223
# Name: 該週總人數, dtype: int64
# 141    241
# Name: 該週總人數, dtype: int64
# 142    267
# Name: 該週總人數, dtype: int64
# 143    175
# Name: 該週總人數, dtype: int64
# 144    167
# Name: 該週總人數, dtype: int64
# 145    261
# Name: 該週總人數, dtype: int64
# 146    226
# Name: 該週總人數, dtype: int64
# 147    197
# Name: 該週總人數, dtype: int64
# 148    236
# Name: 該週總人數, dtype: int64
# 149    198
# Name: 該週總人數, dtype: int64
# 150    264
# Name: 該週總人數, dtype: int64
# 151    213
# Name: 該週總人數, dtype: int64
# 152    248
# Name: 該週總人數, dtype: int64
# 153    185
# Name: 該週總人數, dtype: int64
# 154    210
# Name: 該週總人數, dtype: int64
# 155    207
# Name: 該週總人數, dtype: int64
# 156    0
# Name: 該週總人數, dtype: int64
# 157    217
# Name: 該週總人數, dtype: int64
# 158    274
# Name: 該週總人數, dtype: int64
# 159    262
# Name: 該週總人數, dtype: int64
# 160    224
# Name: 該週總人數, dtype: int64
# 161    214
# Name: 該週總人數, dtype: int64
# 162    16
# Name: 該週總人數, dtype: int64
# 163    166
# Name: 該週總人數, dtype: int64
# 164    256
# Name: 該週總人數, dtype: int64
# 165    227
# Name: 該週總人數, dtype: int64
# 166    231
# Name: 該週總人數, dtype: int64
# 167    251
# Name: 該週總人數, dtype: int64
# 168    228
# Name: 該週總人數, dtype: int64
# 169    202
# Name: 該週總人數, dtype: int64
# 170    217
# Name: 該週總人數, dtype: int64
# 171    241
# Name: 該週總人數, dtype: int64
# 172    163
# Name: 該週總人數, dtype: int64
# 173    212
# Name: 該週總人數, dtype: int64
# 174    206
# Name: 該週總人數, dtype: int64
# 175    194
# Name: 該週總人數, dtype: int64
# 176    182
# Name: 該週總人數, dtype: int64
# 177    194
# Name: 該週總人數, dtype: int64
# 178    211
# Name: 該週總人數, dtype: int64
# 179    187
# Name: 該週總人數, dtype: int64
# 180    187
# Name: 該週總人數, dtype: int64
# 181    177
# Name: 該週總人數, dtype: int64
# 182    200
# Name: 該週總人數, dtype: int64
# 183    219
# Name: 該週總人數, dtype: int64
# 184    208
# Name: 該週總人數, dtype: int64
# 185    197
# Name: 該週總人數, dtype: int64
# 186    206
# Name: 該週總人數, dtype: int64
# 187    193
# Name: 該週總人數, dtype: int64
# 188    190
# Name: 該週總人數, dtype: int64
# 189    198
# Name: 該週總人數, dtype: int64
# 190    209
# Name: 該週總人數, dtype: int64
# 191    231
# Name: 該週總人數, dtype: int64
# 192    233
# Name: 該週總人數, dtype: int64
# 193    236
# Name: 該週總人數, dtype: int64
# 194    164
# Name: 該週總人數, dtype: int64
# 195    262
# Name: 該週總人數, dtype: int64
# 196    185
# Name: 該週總人數, dtype: int64
# 197    145
# Name: 該週總人數, dtype: int64
# 198    157
# Name: 該週總人數, dtype: int64
# 199    218
# Name: 該週總人數, dtype: int64
# 200    213
# Name: 該週總人數, dtype: int64
# 201    246
# Name: 該週總人數, dtype: int64
# 202    212
# Name: 該週總人數, dtype: int64
# 203    233
# Name: 該週總人數, dtype: int64
# 204    177
# Name: 該週總人數, dtype: int64
# 205    170
# Name: 該週總人數, dtype: int64
# 206    200
# Name: 該週總人數, dtype: int64
# 207    214
# Name: 該週總人數, dtype: int64
# 208    230
# Name: 該週總人數, dtype: int64
# 209    224
# Name: 該週總人數, dtype: int64
# 210    231
# Name: 該週總人數, dtype: int64
# 211    217
# Name: 該週總人數, dtype: int64
# 212    101
# Name: 該週總人數, dtype: int64
# 213    12
# Name: 該週總人數, dtype: int64
# 214    214
# Name: 該週總人數, dtype: int64
# 215    256
# Name: 該週總人數, dtype: int64
# 216    201
# Name: 該週總人數, dtype: int64
# 217    180
# Name: 該週總人數, dtype: int64
# 218    249
# Name: 該週總人數, dtype: int64
# 219    242
# Name: 該週總人數, dtype: int64
# 220    270
# Name: 該週總人數, dtype: int64
# 221    254
# Name: 該週總人數, dtype: int64
# 222    190
# Name: 該週總人數, dtype: int64
# 223    230
# Name: 該週總人數, dtype: int64
# 224    223
# Name: 該週總人數, dtype: int64
# 225    239
# Name: 該週總人數, dtype: int64
# 226    233
# Name: 該週總人數, dtype: int64
# 227    233
# Name: 該週總人數, dtype: int64
# 228    146
# Name: 該週總人數, dtype: int64
# 229    202
# Name: 該週總人數, dtype: int64
# 230    127
# Name: 該週總人數, dtype: int64
# 231    90
# Name: 該週總人數, dtype: int64
# 232    62
# Name: 該週總人數, dtype: int64
# 233    69
# Name: 該週總人數, dtype: int64
# 234    69
# Name: 該週總人數, dtype: int64
# 235    179
# Name: 該週總人數, dtype: int64
# 236    208
# Name: 該週總人數, dtype: int64
# 237    135
# Name: 該週總人數, dtype: int64
# 238    142
# Name: 該週總人數, dtype: int64
# 239    159
# Name: 該週總人數, dtype: int64
# 240    143
# Name: 該週總人數, dtype: int64
# 241    155
# Name: 該週總人數, dtype: int64
# 242    155
# Name: 該週總人數, dtype: int64
# 243    159
# Name: 該週總人數, dtype: int64
# 244    149
# Name: 該週總人數, dtype: int64
# 245    174
# Name: 該週總人數, dtype: int64
# 246    214
# Name: 該週總人數, dtype: int64
# 247    254
# Name: 該週總人數, dtype: int64
# 248    245
# Name: 該週總人數, dtype: int64
# 249    239
# Name: 該週總人數, dtype: int64
# 250    279
# Name: 該週總人數, dtype: int64
# 251    333
# Name: 該週總人數, dtype: int64
# 252    289
# Name: 該週總人數, dtype: int64
# 253    257
# Name: 該週總人數, dtype: int64
# 254    255
# Name: 該週總人數, dtype: int64
# 255    199
# Name: 該週總人數, dtype: int64
# 256    246
# Name: 該週總人數, dtype: int64
# 257    224
# Name: 該週總人數, dtype: int64
# 258    227
# Name: 該週總人數, dtype: int64
# 259    224
# Name: 該週總人數, dtype: int64
# 260    219
# Name: 該週總人數, dtype: int64
# 261    256
# Name: 該週總人數, dtype: int64
# 262    216
# Name: 該週總人數, dtype: int64
# 263    106
# Name: 該週總人數, dtype: int64
# 264    89
# Name: 該週總人數, dtype: int64
# 265    209
# Name: 該週總人數, dtype: int64
# 266    265
# Name: 該週總人數, dtype: int64
# 267    274
# Name: 該週總人數, dtype: int64
# 268    279
# Name: 該週總人數, dtype: int64
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [5], in <cell line: 30>()
#      31 for num in range(1, 53,1):
#      32     temp = room5[(room5['年'] == 2018+year) & (room5['週'] == num)]
# ---> 33     people_avg = (temp['前1週人數'].values[0]/7).round(decimals = 2)
#      34     room5.loc[(room5['年'] == 2018+year) & (room5['週'] == num),'前1週平均人數'] = people_avg
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
room5
# Out:
#           住院日期  護理站  成本中心  人數  週     年  該週總人數  該週最多人  前1週人數  前1週最多人  前1週平均人數
# 0   2018-01-07  D15  DLN5  28  1  2018    180   32.0    NaN     NaN      NaN
# 1   2018-01-14  D15  DLN5  25  2  2018    199   34.0  180.0    32.0    25.71
# 2   2018-01-21  D15  DLN5  31  3  2018    195   31.0  199.0    34.0    28.43
# 3   2018-01-28  D15  DLN5  28  4  2018    210   33.0  195.0    31.0    27.86
# 4   2018-02-04  D15  DLN5  28  5  2018    185   28.0  210.0    33.0    30.00
# ..         ...  ...   ...  .. ..   ...    ...    ...    ...     ...      ...
# 265 2023-02-05  D15  DLN5  29  5  2023    209   35.0   89.0    21.0    12.71
# 266 2023-02-12  D15  DLN5  41  6  2023    265   41.0  209.0    35.0    29.86
# 267 2023-02-19  D15  DLN5  38  7  2023    274   43.0  265.0    41.0    37.86
# 268 2023-02-26  D15  DLN5  37  8  2023    279   43.0  274.0    43.0    39.14
# 269 2023-02-28  D15  DLN5  35  9  2023     71   36.0  279.0    43.0    39.86
#
# [270 rows x 11 columns]

# %%
room5.to_csv(f'./五病房人數.csv',index=False, encoding='utf_8_sig')
